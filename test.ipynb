# %%
import matplotlib.pyplot  as plt
import matplotlib.style as s
# %matplotlib inline
from scipy.stats import norm
import numpy as np

# %%
x=[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]

# %%
plt.plot(x,y)

# %%
axes=plt.axes()
axes.set_yticks([0,15,20,30,50,80,101,120])
plt.plot(x,y)

# %%
n = [5,25,50,100,125]

# %%
b = [27,66,133,270,401]
plt.plot(n,b,marker = '+', markersize =15)
plt.xlabel('Number of elements')
plt.ylabel('Time(in microseconds)')
# Out:
# Text(0, 0.5, 'Time(in microseconds)')

# %%
a = [28,79,180,330,492]
plt.plot(n,a,marker='+',markersize=15)
plt.xlabel('Number of elements')
plt.ylabel('Time(in microseconds)')
# Out:
# Text(0, 0.5, 'Time(in microseconds)')

# %%
w = [15,84,3]
plt.plot(n,w,marker='+',markersize=15)
plt.xlabel('Number of elements')
plt.ylabel('Time(in microseconds)')
# Out:
# Text(0, 0.5, 'Time(in microseconds)')
