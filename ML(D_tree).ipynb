# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import sklearn

from pandas import Series, DataFrame
from pylab import rcParams
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn import metrics 
from sklearn.metrics import classification_report

# %%
df=pd.read_csv('loan_data.csv')

# %%
df.sample(15)
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 5423              1         credit_card    0.1287       336.34
# 7395              1  debt_consolidation    0.1025       161.93
# 8715              0  debt_consolidation    0.1286       252.20
# 4955              1  debt_consolidation    0.1531       417.79
# 1231              1         credit_card    0.1317       251.64
# 2901              1           all_other    0.1284       168.09
# 6896              1         credit_card    0.1136       493.67
# 7483              1           all_other    0.1348       169.63
# 6064              1           all_other    0.1878       803.99
# 6661              1      small_business    0.1913       550.81
# 1916              1           all_other    0.1253       127.18
# 2945              1         credit_card    0.2086       902.54
# 1363              1           all_other    0.0907       210.10
# 7170              1      small_business    0.1422       342.85
# ...

# %%
pmap={'small_business':1,'all_other':2,'credit_card':3,'debt_consolidation':4,'educational':5,'home_improvement':6,'major_purchase':7}

# %%
from sklearn.model_selection import train_test_split

# %%
df['purpose']=df['purpose'].map(pmap).astype(int)

# %%
df.sample(15)
# Out:
#       credit.policy  purpose  int.rate  installment  log.annual.inc    dti  \
# 6987              1        5    0.1461       344.76       11.041321   8.46
# 4922              1        6    0.1183       516.89       11.225243  17.26
# 1223              1        2    0.1286       504.40       10.865134  18.14
# 2034              1        1    0.1663       354.70       11.350407  15.61
# 4382              1        3    0.1392        54.62       11.184421  17.65
# 1854              1        2    0.1189       165.82       10.714418   5.47
# 2118              1        3    0.1474       328.10       10.748798  19.81
# 3267              1        4    0.1347       542.77       11.608272  21.82
# 890               1        4    0.1387       388.91       11.002100  24.48
# 1893              1        2    0.1505       260.19       11.379394   9.08
# 1462              1        1    0.1178       331.10       10.805760  17.67
# ...

# %%
X=df[['int.rate','inq.last.6mths']]

# %%
X_train, X_test, y_train, y_test =train_test_split(X,df['not.fully.paid'], test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
pr=dtree.predict(X_test)

# %%
dtree.score(X_train,y_train)
# Out:
# 0.8687350835322196

# %%
dtree.score(X_test,y_test)
# Out:
# 0.837508698677801

# %%
df.corr()
# Out:
#                    credit.policy   purpose  int.rate  installment  \
# credit.policy           1.000000  0.024402 -0.294089     0.058770
# purpose                 0.024402  1.000000 -0.042980     0.007168
# int.rate               -0.294089 -0.042980  1.000000     0.276140
# installment             0.058770  0.007168  0.276140     1.000000
# log.annual.inc          0.034906 -0.005125  0.056383     0.448102
# dti                    -0.090901  0.020044  0.220006     0.050202
# fico                    0.348319 -0.008355 -0.714821     0.086039
# days.with.cr.line       0.099026  0.013769 -0.124022     0.183297
# revol.bal              -0.187518 -0.048909  0.092527     0.233625
# revol.util             -0.104095 -0.000860  0.464837     0.081356
# inq.last.6mths         -0.535511 -0.006826  0.202780    -0.010419
# delinq.2yrs            -0.076318 -0.008616  0.156079    -0.004368
# pub.rec                -0.054243  0.012115  0.098162    -0.032760
# ...
