# 209512  RSM00032076  2015-12-31    TMAX         -80
#
# [650832 rows x 4 columns]

# %%
#MAking two  more columns year and month
df['Year'] = df['Date'].apply(lambda x: x[:4])
df['Month-Day'] = df['Date'].apply(lambda x: x[5:])
df = df[df['Month-Day'] != '02-29']
df.head()
# Out:
#             ID        Date Element  Data_Value  Year Month-Day
# 0  CHM00053646  2005-11-14    TMIN         -87  2005     11-14
# 1  CHM00054102  2014-09-20    TMAX         175  2014     09-20
# 2  CHM00050727  2011-08-05    TMAX         271  2011     08-05
# 3  CHM00053646  2014-08-24    TMAX         249  2014     08-24
# 4  RSM00031913  2009-07-12    TMAX         230  2009     07-12

# %%
#Seprating value for Tmax nad Tmin
t_min = df[(df['Element'] == 'TMIN')]
t_max = df[(df['Element'] == 'TMAX')]
#getting data from 2005 to 2014 except 2015
tmin = df[(df['Element'] == 'TMIN') & (df['Year'] != '2015')]
tmax = df[(df['Element'] == 'TMAX') & (df['Year'] != '2015')]

# %%
temp_min = tmin.groupby('Month-Day')['Data_Value'].agg({'temp_min_mean': np.mean})
temp_max = tmax.groupby('Month-Day')['Data_Value'].agg({'temp_max_mean': np.mean})

# %%
temp_min_15_tmp = t_min[t_min['Year'] == '2015']
temp_max_15_tmp = t_max[t_max['Year'] == '2015']

# %%
temp_min_15 = temp_min_15_tmp.groupby('Month-Day')['Data_Value'].agg({'temp_min_15_mean': np.mean})
temp_max_15 = temp_max_15_tmp.groupby('Month-Day')['Data_Value'].agg({'temp_max_15_mean': np.mean})

# %%
temp_min = temp_min.reset_index()
temp_max = temp_max.reset_index()

temp_min_15 = temp_min_15.reset_index()
temp_max_15 = temp_max_15.reset_index()

# %%
broken_min = (temp_min_15[temp_min_15['temp_min_15_mean'] < temp_min['temp_min_mean']]).index.tolist()
broken_max = (temp_max_15[temp_max_15['temp_max_15_mean'] > temp_max['temp_max_mean']]).index.tolist()

# %%
plt.figure()
plt.plot(temp_min['temp_min_mean'], 'm', alpha = 0.5, label = 'Record Low')
plt.plot(temp_max['temp_max_mean'], 'r', alpha = 0.5, label = 'Record High')


plt.scatter(broken_min, temp_min_15['temp_min_15_mean'].iloc[broken_min], s = 1, c = 'k', label = 'Broken Min')
plt.scatter(broken_max, temp_max_15['temp_max_15_mean'].iloc[broken_max], s = 1, c = 'b', label = 'Broken Max')

plt.xlabel('Month')
plt.ylabel('Temperature (Tenths of Degrees C)')
plt.title('Extreme Temperatures of 2015 against 2005-2014\n Beijing, China')

plt.gca().fill_between(range(len(temp_min)), 
                       temp_min['temp_min_mean'], temp_max['temp_max_mean'], 
                       facecolor='grey', 
                       alpha=0.2)

plt.gca().axis([-5, 370, -400, 400])
plt.legend(frameon = False)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

a = [0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330]
b = [i+15 for i in a]

Month_name = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(b, Month_name)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x7ff52958db70>,
#   <matplotlib.axis.XTick at 0x7ff5295871d0>,
#   <matplotlib.axis.XTick at 0x7ff52956be10>,
#   <matplotlib.axis.XTick at 0x7ff5294e4668>,
#   <matplotlib.axis.XTick at 0x7ff5294f36a0>,
#   <matplotlib.axis.XTick at 0x7ff5294fa0b8>,
#   <matplotlib.axis.XTick at 0x7ff5294faa90>,
#   <matplotlib.axis.XTick at 0x7ff5295014a8>,
#   <matplotlib.axis.XTick at 0x7ff529501e80>,
#   <matplotlib.axis.XTick at 0x7ff529506898>,
#   <matplotlib.axis.XTick at 0x7ff52950f2b0>,
#   <matplotlib.axis.XTick at 0x7ff52950fc88>],
#  <a list of 12 Text xticklabel objects>)
